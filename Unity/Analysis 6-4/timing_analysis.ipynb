# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dat = np.load('timing_data.npy')
print(dat.shape)
print(dat)
# Out:
# (2, 501)
# [[   0.            5.           10.         ... 2490.
#   2495.         2500.        ]
#  [   6.77662468    3.14134479    3.17626095 ...    6.78406978
#      6.79181933    6.76029897]]

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot()

ax.plot(dat[0, :20], dat[1, :20])

plt.show()
