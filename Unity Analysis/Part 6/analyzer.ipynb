# %%
# Importing crap
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../')

import numpy as np
import pandas as pd
import numexpr

import matplotlib.pyplot as plt
import matplotlib.patches as patches

import IRSMicroLensing.IRSFunctions as IRSF
import IRSMicroLensing.IRSCaustics as IRSC

import VBMicrolensing
import MulensModel as mm
import os

import csv

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['figure.titlesize'] = 20
plt.rcParams['figure.titleweight'] = 'bold'
plt.rcParams['figure.figsize'] = (14, 8)
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['figure.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.title_fontsize'] = 16
plt.rcParams['legend.fontsize'] = 16
plt.rcParams['mathtext.fontset'] = 'cm'

# %%
sim_sun_jupiter = IRSC.caustic_reader('../../Unity/Simulations/Part_6_Multiplanet_Collection/sun_jupiter.pkl')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sim_sun_jupiter = IRSC.caustic_reader('../../Unity/Simulations/Part_6_Multiplanet_Collection/sun_jupiter.pkl')
#
# File ~/Documents/GitHub/NBLens/Unity Analysis/Part 6/../../IRSMicroLensing/IRSCaustics.py:1545, in caustic_reader(file_path)
#    1543 def caustic_reader(file_path: str) -> IRSCaustics:
#    1544     with open(file_path, 'rb') as f:
# -> 1545         return pickle.load(f)
#
# File ~/Documents/GitHub/NBLens/Unity Analysis/Part 6/../../IRSMicroLensing/IRSCausticsGPU.py:3
#       1 from concurrent.futures import as_completed
#       2 from .imports import *
# ----> 3 from .IRSMainGPU import IRSMain
#       4 import cupy as cp
#       6 _pack_conjugate = cp.ElementwiseKernel(
#       7     'float64 re, float64 im',
#       8     'complex128 z',
#       9     'z = complex<double>(re, -im)',
#      10     'pack_conjugate'
#      11 )
#
# File ~/Documents/GitHub/NBLens/Unity Analysis/Part 6/../../IRSMicroLensing/IRSMainGPU.py:2
#       1 from .imports import *
# ----> 2 import cupy as cp
#       4 class IRSMain(object):
#       5     '''
#       6     Calculates image fluxes and magnifications for gravitational microlensing
#       7
#    (...)
#      45         Maps source brightnesses per pixel to image using translated image pixels.
#      46     '''
#
# ModuleNotFoundError: No module named 'cupy'
